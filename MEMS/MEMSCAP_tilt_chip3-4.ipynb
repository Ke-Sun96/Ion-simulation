# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip as qt
from scipy.optimize import curve_fit
import pandas as pd

# %%
def plot_Angle(file_name, sheet_name):
    dfs = pd.read_excel(file_name, sheet_name=sheet_name)
    voltages = dfs.iloc[:,0]
    avg = dfs.iloc[:,4]
    std = dfs.iloc[:,5]
    title = dfs.columns[0]
    plt.errorbar(voltages, avg, yerr=std,ls='-',marker='o',mec='firebrick',ecolor='firebrick',mfc='pink')
    plt.xlabel('Applied voltage (V)')
    plt.ylabel('Angle (Deg)')
    plt.title(str(title))
    return dfs

# %%
file_name = 'MEMSCAP.xlsx'
sheet_name = 'C3A2U'
C3A2U = plot_Angle(file_name, sheet_name)
C3A2U
# Out:
#     C3A2U   Meas 1   Meas 2   Meas 3  Avg angle (Deg)  std (Deg)  Unnamed: 6  \
# 0       0 -0.00337 -0.00499 -0.00489        -0.004417   0.000908         NaN
# 1      10 -0.00115 -0.00158  0.00325         0.000173   0.002673         NaN
# 2      20  0.00779  0.00871  0.00324         0.006580   0.002929         NaN
# 3      30  0.01873  0.02582  0.02338         0.022643   0.003602         NaN
# 4      40  0.04601  0.05297  0.05001         0.049663   0.003493         NaN
# 5      50  0.08945  0.10327  0.09843         0.097050   0.007013         NaN
# 6      60  0.15169  0.16386  0.16102         0.158857   0.006367         NaN
# 7      70  0.24389  0.25494  0.25130         0.250043   0.005631         NaN
# 8      80  0.39428  0.39933  0.39898         0.397530   0.002820         NaN
# 9      90  0.54311  0.55191  0.54982         0.548280   0.004598         NaN
# 10    100  0.75182  0.76089  0.76475         0.759153   0.006638         NaN
# ...

# %%
file_name = 'MEMSCAP.xlsx'
sheet_name = 'C3A2D'
C3A2D = plot_Angle(file_name, sheet_name)
C3A2D
# Out:
#     C3A2D   Meas 1   Meas 2   Meas 3  Avg angle (Deg)  std (Deg)  Unnamed: 6  \
# 0     0.0  0.00123 -0.00042  0.00494         0.001917   0.002745         NaN
# 1    10.0 -0.00472 -0.00086 -0.00420        -0.003260   0.002095         NaN
# 2    20.0 -0.00538 -0.00482 -0.00213        -0.004110   0.001737         NaN
# 3    30.0 -0.02825 -0.02262 -0.01921        -0.023360   0.004565         NaN
# 4    40.0 -0.05599 -0.05470 -0.05713        -0.055940   0.001216         NaN
# 5    50.0 -0.11015 -0.10527 -0.10621        -0.107210   0.002589         NaN
# 6    60.0 -0.18578 -0.17714 -0.17630        -0.179740   0.005248         NaN
# 7    70.0 -0.28075 -0.27378 -0.27031        -0.274947   0.005317         NaN
# 8    80.0 -0.39293 -0.38774 -0.38778        -0.389483   0.002985         NaN
# 9    90.0 -0.56488 -0.55786 -0.55536        -0.559367   0.004936         NaN
# 10    NaN      NaN      NaN      NaN              NaN        NaN         NaN
# ...

# %%
file_name = 'MEMSCAP.xlsx'
sheet_name = 'C4A3U'
C4A3U = plot_Angle(file_name, sheet_name)
C4A3U
# Out:
#     C4A3U   Meas 1   Meas 2   Meas 3  Avg angle (Deg)  std (Deg)  Unnamed: 6  \
# 0     0.0 -0.00281  0.00247 -0.00370        -0.001347   0.003335         NaN
# 1    10.0  0.01489  0.01410  0.01774         0.015577   0.001915         NaN
# 2    15.0  0.01763  0.02346  0.02600         0.022363   0.004291         NaN
# 3    20.0  0.03183  0.03111  0.03435         0.032430   0.001701         NaN
# 4    25.0  0.02715  0.03056  0.03564         0.031117   0.004272         NaN
# 5    30.0  0.03143  0.03130  0.03531         0.032680   0.002279         NaN
# 6    35.0  0.03272  0.02979  0.03220         0.031570   0.001563         NaN
# 7    40.0  0.03657  0.03697  0.04487         0.039470   0.004681         NaN
# 8    45.0  0.04727  0.04664  0.04826         0.047390   0.000817         NaN
# 9    50.0  0.05841  0.05827  0.06137         0.059350   0.001751         NaN
# 10   55.0  0.07243  0.07269  0.07558         0.073567   0.001748         NaN
# ...

# %%
file_name = 'MEMSCAP.xlsx'
sheet_name = 'C4A3D'
C4A3D = plot_Angle(file_name, sheet_name)
C4A3D
# Out:
#    C4A3D   Meas 1   Meas 2   Meas 3  Avg angle (Deg)  std (Deg)  Unnamed: 6  \
# 0    0.0 -0.00767      NaN      NaN        -0.007670   0.000000         NaN
# 1   10.0 -0.01521 -0.01570 -0.01582        -0.015577   0.000323         NaN
# 2   15.0 -0.02315 -0.02538 -0.02736        -0.025297   0.002106         NaN
# 3   20.0 -0.03062 -0.02706 -0.02753        -0.028403   0.001934         NaN
# 4   25.0 -0.03864 -0.03945 -0.03348        -0.037190   0.003238         NaN
# 5   30.0 -0.05408 -0.05638 -0.05292        -0.054460   0.001761         NaN
# 6   35.0 -0.06443 -0.06423 -0.05972        -0.062793   0.002663         NaN
# 7    NaN      NaN      NaN      NaN              NaN        NaN         NaN
# 8    NaN      NaN      NaN      NaN              NaN        NaN         NaN
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN
# 1         NaN        NaN        NaN
# 2         NaN        NaN        NaN
# 3         NaN        NaN        NaN
# ...

# %%
file_name = 'MEMSCAP_2.xlsx'
sheet_name = 'C3A3U'
C3A3U = plot_Angle(file_name, sheet_name)
C3A3U
# Out:
#    C3A3U   Meas 1   Meas 2   Meas 3  Avg angle (Deg)  std (Deg)  Unnamed: 6  \
# 0    0.0 -0.00425  0.00354  0.01371         0.008625   0.007191         NaN
# 1   15.0  0.02083  0.02297  0.03434         0.026047   0.007262         NaN
# 2   30.0  0.07466  0.08173  0.09405         0.083480   0.009813         NaN
# 3   40.0  0.12144  0.13050  0.14137         0.131103   0.009979         NaN
# 4   50.0  0.21614  0.22129  0.22519         0.220873   0.004539         NaN
# 5   60.0  0.32991  0.33670  0.34632         0.337643   0.008246         NaN
# 6   66.0  0.41910  0.42691  0.43071         0.425573   0.005919         NaN
# 7   72.0  0.51746  0.52349  0.53222         0.524390   0.007421         NaN
# 8   76.1  0.57304  0.57967  0.59100         0.581237   0.009082         NaN
#
#               Unnamed: 7
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# ...

# %%
file_name = 'MEMSCAP_2.xlsx'
sheet_name = 'C3A3D'
C3A3D = plot_Angle(file_name, sheet_name)
C3A3D
# Out:
#     C3A3D   Meas 1   Meas 2   Meas 3  Avg angle (Deg)  std (Deg)  Unnamed: 6  \
# 0     0.0 -0.01736 -0.01146  0.00110        -0.005180   0.008881         NaN
# 1    15.0 -0.03839 -0.03046 -0.02789        -0.032247   0.005473         NaN
# 2    30.0 -0.10196 -0.09789 -0.09120        -0.097017   0.005433         NaN
# 3    40.0 -0.12659 -0.12178 -0.12061        -0.122993   0.003169         NaN
# 4    50.0 -0.20050 -0.19430 -0.18845        -0.194417   0.006026         NaN
# 5    60.0 -0.28441 -0.28059 -0.28156        -0.282187   0.001986         NaN
# 6    66.0 -0.34701 -0.33963 -0.33175        -0.339463   0.007631         NaN
# 7    72.0 -0.41786 -0.40891 -0.40686        -0.411210   0.005850         NaN
# 8    76.4 -0.46720 -0.46431 -0.45955        -0.463687   0.003863         NaN
# 9    80.0 -0.49841 -0.49261 -0.49032        -0.493780   0.004170         NaN
# 10   84.0 -0.59623 -0.59031 -0.58851        -0.591683   0.004039         NaN
# ...

# %%
file_name = 'MEMSCAP_2.xlsx'
sheet_name = 'C3E5U'
C3E5U = plot_Angle(file_name, sheet_name)
C3E5U
# Out:
#     C3E5U   Meas 1   Meas 2  Unnamed: 3  Avg angle (Deg)  std (Deg)
# 0     0.0 -0.00306 -0.00516         NaN        -0.004110   0.001485
# 1    15.0  0.00189  0.00002         NaN         0.000955   0.001322
# 2    30.0  0.03614  0.03622         NaN         0.036180   0.000057
# 3    40.0  0.08085  0.07618         NaN         0.078515   0.003302
# 4    50.0  0.14366  0.13256         NaN         0.138110   0.007849
# 5    60.0  0.21314  0.20842         NaN         0.210780   0.003338
# 6    65.6  0.28407  0.26989         NaN         0.276980   0.010027
# 7    71.7  0.34058  0.32310         NaN         0.331840   0.012360
# 8    79.1  0.43505  0.43222         NaN         0.433635   0.002001
# 9    84.0  0.52642  0.51110         NaN         0.518760   0.010833
# 10   87.9  0.58993  0.58225         NaN         0.586090   0.005431

# %%
file_name = 'MEMSCAP_2.xlsx'
sheet_name = 'C3E5D'
C3E5D = plot_Angle(file_name, sheet_name)
C3E5D
# Out:
#    C3E5D   Meas 1   Meas 2  Unnamed: 3  Avg angle (Deg)  std (Deg)
# 0      0 -0.00933 -0.01031         NaN        -0.009820   0.000693
# 1     15 -0.03240 -0.03257         NaN        -0.032485   0.000120
# 2     30 -0.09284 -0.09562         NaN        -0.094230   0.001966
# 3     40 -0.15727 -0.16438         NaN        -0.160825   0.005028
# 4     50 -0.23234 -0.23435         NaN        -0.233345   0.001421
# 5     60 -0.30344 -0.30691         NaN        -0.305175   0.002454

# %%
file_name = 'MEMSCAP_2.xlsx'
sheet_name = 'C4B1U'
C4B1U = plot_Angle(file_name, sheet_name)
C4B1U
# Out:
#      C4B1U    Meas 1   Meas 2  Unnamed: 3  Avg angle (Deg)  std (Deg)
# 0     0.00  0.006330  0.00898         NaN         0.007655   0.001874
# 1    15.00  0.001995  0.01654         NaN         0.009267   0.010285
# 2    30.63  0.055900  0.05509         NaN         0.055495   0.000573
# 3    40.00  0.085220  0.08971         NaN         0.087465   0.003175
# 4    50.00  0.106370  0.10449         NaN         0.105430   0.001329
# 5    60.00  0.107860  0.10866         NaN         0.108260   0.000566
# 6    72.70  0.156200  0.15147         NaN         0.153835   0.003345
# 7    83.80  0.191700  0.19580         NaN         0.193750   0.002899
# 8    89.30  0.230780  0.22230         NaN         0.226540   0.005996
# 9    96.80  0.271660  0.26453         NaN         0.268095   0.005042
# 10  103.30  0.317540  0.31815         NaN         0.317845   0.000431
# 11  108.10  0.365560  0.36033         NaN         0.362945   0.003698
# ...

# %%
file_name = 'MEMSCAP_2.xlsx'
sheet_name = 'C4B1D'
C4B1D = plot_Angle(file_name, sheet_name)
C4B1D
# Out:
#     C4B1D   Meas 1   Meas 2  Unnamed: 3  Avg angle (Deg)  std (Deg)
# 0     0.0 -0.00081 -0.00023         NaN        -0.000520   0.000410
# 1    15.2 -0.01008 -0.01185         NaN        -0.010965   0.001252
# 2    30.3 -0.02220 -0.02318         NaN        -0.022690   0.000693
# 3    40.0 -0.04093 -0.03939         NaN        -0.040160   0.001089
# 4    50.0 -0.07730 -0.07589         NaN        -0.076595   0.000997
# 5    60.0 -0.12323 -0.12161         NaN        -0.122420   0.001146
# 6    73.0 -0.19595 -0.19425         NaN        -0.195100   0.001202
# 7    82.0 -0.26233 -0.25978         NaN        -0.261055   0.001803
# 8    87.0 -0.30383 -0.30304         NaN        -0.303435   0.000559
# 9    93.6 -0.35548 -0.36574         NaN        -0.360610   0.007255
# 10  102.1 -0.46004 -0.46508         NaN        -0.462560   0.003564
# 11  107.4 -0.55139 -0.55458         NaN        -0.552985   0.002256
# 12  109.8 -0.61405 -0.61700         NaN        -0.615525   0.002086
# ...

# %%
file_name = 'MEMSCAP_2.xlsx'
sheet_name = 'C4A6U'
C4A6U = plot_Angle(file_name, sheet_name)
C4A6U
# Out:
#     C4A6U   Meas 1   Meas 2  Unnamed: 3  Avg angle (Deg)  std (Deg)
# 0     0.0  0.00436  0.00302         NaN         0.003690   0.000948
# 1    15.1  0.01442  0.01444         NaN         0.014430   0.000014
# 2    30.0  0.04033  0.04073         NaN         0.040530   0.000283
# 3    40.5  0.07716  0.07762         NaN         0.077390   0.000325
# 4    50.7  0.11222  0.11011         NaN         0.111165   0.001492
# 5    60.0  0.15062  0.15022         NaN         0.150420   0.000283
# 6    67.8  0.19022  0.19137         NaN         0.190795   0.000813
# 7    78.1  0.24796  0.24974         NaN         0.248850   0.001259
# 8    85.3  0.27877  0.28185         NaN         0.280310   0.002178
# 9    90.4  0.31409  0.31480         NaN         0.314445   0.000502
# 10   97.6  0.35779  0.36132         NaN         0.359555   0.002496
# 11  105.9  0.41915  0.42335         NaN         0.421250   0.002970
# 12  112.6  0.49120  0.49599         NaN         0.493595   0.003387
# ...

# %%
file_name = 'MEMSCAP_2.xlsx'
sheet_name = 'C4A6D'
C4A6D = plot_Angle(file_name, sheet_name)
C4A6D
# Out:
#    C4A6D   Meas 1   Meas 2  Unnamed: 3  Avg angle (Deg)  std (Deg)  \
# 0    0.0  0.00900  0.01111         NaN         0.010055   0.001492
# 1   15.1 -0.00212 -0.00310         NaN        -0.002610   0.000693
# 2   30.3 -0.01331 -0.01323         NaN        -0.013270   0.000057
# 3   40.1 -0.03953 -0.03659         NaN        -0.038060   0.002079
# 4   50.0 -0.05433 -0.05580         NaN        -0.055065   0.001039
# 5   60.0 -0.07168 -0.07102         NaN        -0.071350   0.000467
# 6   75.2 -0.11573 -0.11667         NaN        -0.116200   0.000665
# 7   81.1 -0.14906 -0.14577         NaN        -0.147415   0.002326
# 8   87.4 -0.17658 -0.17580         NaN        -0.176190   0.000552
# 9   92.2 -0.19333 -0.19066         NaN        -0.191995   0.001888
#
#    Unnamed: 6    Unnamed: 7
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
# 5         NaN           NaN
# ...

# %%
def plot_Angle_2(file_name, sheet_name):
    dfs = pd.read_excel(file_name, sheet_name=sheet_name)
    voltages = dfs.iloc[:,0]
    avg = dfs.iloc[:,3]
    std = dfs.iloc[:,4]
    title = dfs.columns[0]
    plt.errorbar(voltages, avg, yerr=std,ls='-',marker='o',mec='firebrick',ecolor='firebrick',mfc='pink')
    plt.xlabel('Applied voltage (V)')
    plt.ylabel('Angle (Deg)')
    plt.title(str(title))
    return dfs

# %%
file_name = 'Sample3.xlsx'
sheet_name = 'C4B1U'
C4B1U_3 = plot_Angle_2(file_name, sheet_name)
C4B1U_3
# Out:
#     C4B1U (V)   Meas 1   Meas 2  Avg angle (Deg)  std (Deg)  Unnamed: 5  \
# 0         0.0  0.00474  0.00478         0.004760   0.000028         NaN
# 1        20.0  0.02323  0.02809         0.025660   0.003437         NaN
# 2        40.2  0.09952  0.09652         0.098020   0.002121         NaN
# 3        55.0  0.18487  0.18782         0.186345   0.002086         NaN
# 4        62.0  0.24051  0.24406         0.242285   0.002510         NaN
# 5        70.0  0.30880  0.30838         0.308590   0.000297         NaN
# 6        76.8  0.39384  0.39384         0.393840   0.000000         NaN
# 7        81.7  0.47774  0.47785         0.477795   0.000078         NaN
# 8        86.5  0.55549  0.55202         0.553755   0.002454         NaN
# 9        91.1  0.63635  0.63804         0.637195   0.001195         NaN
# 10       95.8  0.73358  0.73999         0.736785   0.004533         NaN
# 11      101.1  0.86165  0.86687         0.864260   0.003691         NaN
# ...

# %%
file_name = 'Sample3.xlsx'
sheet_name = 'C4B2D'
C4B2D_3 = plot_Angle_2(file_name, sheet_name)
C4B2D_3
# Out:
#    C4B2D (V)   Meas 1   Meas 2  Avg angle (Deg)  std (Deg)  Unnamed: 5  \
# 0        0.0 -0.00125  0.00111        -0.000070   0.001669         NaN
# 1       20.0 -0.02270 -0.02028        -0.021490   0.001711         NaN
# 2       35.0 -0.07024 -0.06925        -0.069745   0.000700         NaN
# 3       50.0 -0.14506 -0.13731        -0.141185   0.005480         NaN
# 4       60.0 -0.21680 -0.20816        -0.212480   0.006109         NaN
# 5       70.0 -0.29189 -0.28958        -0.290735   0.001633         NaN
# 6       80.3 -0.43772 -0.43537        -0.436545   0.001662         NaN
# 7        NaN      NaN      NaN              NaN        NaN         NaN
# 8        NaN      NaN      NaN              NaN        NaN         NaN
#
#       Unnamed: 6          Unnamed: 7
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
# ...

# %%
file_name = 'Sample3.xlsx'
sheet_name = 'C4A4D'
C4A4D_3 = plot_Angle_2(file_name, sheet_name)
C4A4D_3
# Out:
#    C4A4D (V)   Meas 1   Meas 2  Avg angle (Deg)  std (Deg)  Unnamed: 5  \
# 0        0.0  0.00144  0.00056         0.001000   0.000622         NaN
# 1       20.0 -0.02438 -0.02748        -0.025930   0.002192         NaN
# 2       35.0 -0.07320 -0.07326        -0.073230   0.000042         NaN
# 3       50.0 -0.15139 -0.15495        -0.153170   0.002517         NaN
# 4       60.0 -0.22648 -0.22798        -0.227230   0.001061         NaN
# 5       70.0 -0.32105 -0.32324        -0.322145   0.001549         NaN
# 6       80.3 -0.43839 -0.44203        -0.440210   0.002574         NaN
# 7       86.0 -0.52438 -0.52413        -0.524255   0.000177         NaN
# 8        NaN      NaN      NaN              NaN        NaN         NaN
#
#        Unnamed: 6
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8  burnt at 93.1V

# %%
def plot_Angle_3(file_name, sheet_name):
    dfs = pd.read_excel(file_name, sheet_name=sheet_name)
    voltages = dfs.iloc[:,0]
    avg = dfs.iloc[:,1]
    title = dfs.columns[0]
    plt.plot(voltages, avg, ls='-',marker='o',mec='firebrick',mfc='pink')
    plt.xlabel('Applied voltage (V)')
    plt.ylabel('Angle (Deg)')
    plt.title(str(title))
    return dfs

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C4A1D'
C4A1D_2 = plot_Angle_3(file_name, sheet_name)
C4A1D_2
# Out:
#    C4A1D  Unnamed: 1  Unnamed: 2  \
# 0    0.0     0.00324         NaN
# 1   40.0    -0.12248         NaN
# 2   50.0    -0.18917         NaN
# 3   60.0    -0.27189         NaN
# 4   67.5    -0.36333         NaN
# 5   74.7    -0.45067         NaN
# 6    NaN         NaN        80.3
# 7    NaN         NaN         NaN
# 8    NaN         NaN         NaN
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                mirror becomes flat
# 7                           GND electrode remains OK
# 8  Resistance between A1D and GND becomes 14.47kO...

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C4B2U'
C4B2U_2 = plot_Angle_3(file_name, sheet_name)
C4B2U_2
# Out:
#    C4B2U  Unnamed: 1  Unnamed: 2  \
# 0    0.0     0.00986         NaN
# 1   30.0     0.07402         NaN
# 2   40.0     0.11762         NaN
# 3   50.0     0.19324         NaN
# 4   60.0     0.27779         NaN
# 5    NaN         NaN         NaN
# 6    NaN         NaN         NaN
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                         shorted but GND remains OK
# 6  resistance between B2U and GND becomes 24.2Ohm...

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C4B1U'
C4B1U_2 = plot_Angle_3(file_name, sheet_name)
C4B1U_2
# Out:
#    C4B1U  Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0   0.00     0.00123         NaN        NaN
# 1  34.50     0.08032         NaN        NaN
# 2  45.12     0.13287         NaN        NaN
# 3  55.72     0.21893         NaN        NaN
# 4  66.50     0.33032         NaN        NaN
# 5  72.20     0.39745         NaN        NaN
# 6  79.50     0.51130         NaN        NaN
# 7  85.00     0.60446         NaN        NaN
# 8  89.50     0.71307         NaN        NaN
# 9  94.20     0.83596         NaN  GND burnt

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C4A6U'
C4A6U_2 = plot_Angle_3(file_name, sheet_name)
C4A6U_2
# Out:
#    C4A6U  Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0   0.00    -0.00448         NaN         NaN
# 1  35.28     0.07435         NaN         NaN
# 2  44.53     0.11211         NaN         NaN
# 3  53.52     0.17859         NaN         NaN
# 4    NaN         NaN        60.0  GND burnt

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C4A5U'
C4A5U_2 = plot_Angle_3(file_name, sheet_name)
C4A5U_2
# Out:
#     C4A5U  Unnamed: 1
# 0    0.00     0.00322
# 1   35.18     0.08309
# 2   45.23     0.13387
# 3   56.59     0.21213
# 4   62.38     0.26786
# 5   67.50     0.31131
# 6   73.50     0.38399
# 7   77.50     0.43224
# 8   81.60     0.49056
# 9   85.60     0.56408
# 10  88.90     0.62141
# 11  92.20     0.68415
# 12  94.70     0.74495

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C4A5D'
C4A5D_2 = plot_Angle_3(file_name, sheet_name)
C4A5D_2
# Out:
#    C4A5D  Unnamed: 1  Unnamed: 2  \
# 0   0.00    -0.00059         NaN
# 1  35.54    -0.08454         NaN
# 2  45.60    -0.13541         NaN
# 3  53.66    -0.19064         NaN
# 4  63.41    -0.27178         NaN
# 5  68.50    -0.32838         NaN
# 6  73.00    -0.37672         NaN
# 7  77.80    -0.43810         NaN
# 8  83.20    -0.51222         NaN
# 9  85.60         NaN         NaN
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  resistance between A5D and GND becomes 10.99kO...

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C4A4D'
C4A4D_2 = plot_Angle_3(file_name, sheet_name)
C4A4D_2
# Out:
#    C4A4D  Unnamed: 1  Unnamed: 2  \
# 0    0.0     0.00906         NaN
# 1   35.0    -0.07339         NaN
# 2   45.0    -0.12501         NaN
# 3   54.0    -0.18412         NaN
# 4   63.2    -0.26008         NaN
# 5   73.6    -0.36757         NaN
# 6   82.7    -0.49039         NaN
# 7   87.9    -0.57750         NaN
# 8    NaN         NaN         NaN
#
#                                        Unnamed: 3
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7  resistance between A4D and GND becomes 137kOhm
# 8                                GND remains fine

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C3A4U'
C3A4U_2 = plot_Angle_3(file_name, sheet_name)
C3A4U_2
# Out:
#     C3A4U  Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0    0.00     0.00414         NaN        NaN
# 1   35.65     0.13953         NaN        NaN
# 2   43.16     0.18935         NaN        NaN
# 3   47.99     0.25260         NaN        NaN
# 4   52.12     0.29960         NaN        NaN
# 5   56.38     0.36220         NaN        NaN
# 6   60.04     0.41172         NaN        NaN
# 7   63.92     0.48692         NaN        NaN
# 8   66.90     0.54087         NaN        NaN
# 9   69.50     0.59829         NaN        NaN
# 10  72.70     0.66869         NaN        NaN
# 11  76.20     0.76734         NaN        NaN
# 12  78.20     0.83494         NaN        NaN
# 13  80.80     0.92804         NaN        NaN
# 14  83.40     1.04490         NaN        NaN
# 15  84.90     1.12960         NaN        NaN
# 16  86.00     1.20299         NaN        NaN
# 17    NaN         NaN        87.1  GND burnt

# %%
file_name = 'Sample2.xlsx'
sheet_name = 'C3E5D'
C3E5D_2 = plot_Angle_3(file_name, sheet_name)
C3E5D_2
# Out:
#     C3E5D  Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0    0.00     0.00022         NaN        NaN
# 1   35.00    -0.12069         NaN        NaN
# 2   45.28    -0.21466         NaN        NaN
# 3   50.58    -0.27913         NaN        NaN
# 4   55.72    -0.34888         NaN        NaN
# 5   60.40    -0.41948         NaN        NaN
# 6   67.20    -0.54281         NaN        NaN
# 7   70.60    -0.63147         NaN        NaN
# 8   74.30    -0.73453         NaN        NaN
# 9   77.60    -0.84217         NaN        NaN
# 10  80.80    -0.96835         NaN        NaN
# 11  83.90    -1.13134         NaN        NaN
# 12  86.50    -1.31197         NaN        NaN
# 13  87.80    -1.47685         NaN        NaN
# 14    NaN         NaN        88.7  GND burnt

# %% [markdown]
# ## Compare different chips

# %%
V31 = C3A2U.iloc[:,0]
avg31 = C3A2U.iloc[:,4]
std31 = C3A2U.iloc[:,5]

V32 = C3A3U.iloc[:,0]
avg32 = C3A3U.iloc[:,4]
std32 = C3A3U.iloc[:,5]

V33 = C3E5U.iloc[:,0]
avg33 = C3E5U.iloc[:,4]
std33 = C3E5U.iloc[:,5]

V34 = C3A4U_2.iloc[:,0]
avg34 = C3A4U_2.iloc[:,1]


V41 = C4A3U.iloc[:,0]
avg41 = C4A3U.iloc[:,4]
std41 = C4A3U.iloc[:,5]

V42 = C4B1U.iloc[:,0]
avg42 = C4B1U.iloc[:,4]
std42 = C4B1U.iloc[:,5]

V43 = C4A6U.iloc[:,0]
avg43 = C4A6U.iloc[:,4]
std43 = C4A6U.iloc[:,5]

V44 = C4B1U_3.iloc[:,0]
avg44 = C4B1U_3.iloc[:,3]
std44 = C4B1U_3.iloc[:,4]

V45 = C4B2U_2.iloc[:,0]
avg45 = C4B2U_2.iloc[:,1]

V46 = C4B1U_2.iloc[:,0]
avg46 = C4B1U_2.iloc[:,1]

V47 = C4A6U_2.iloc[:,0]
avg47 = C4A6U_2.iloc[:,1]

V48 = C4A5U_2.iloc[:,0]
avg48 = C4A5U_2.iloc[:,1]

plt.figure(figsize = (12,9))

plt.errorbar(V31, avg31, yerr=std31,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3A2U')
plt.errorbar(V32, avg32, yerr=std32,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3A3U')
plt.errorbar(V33, avg33, yerr=std33,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3E5U')
plt.plot(V34, avg34, ls='-',marker='s',mec='firebrick',mfc='pink',label = 'C3A4U_2')
plt.errorbar(V41, avg41, yerr=std41,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A3U')
plt.errorbar(V42, avg42, yerr=std42,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4B1U')
plt.errorbar(V43, avg43, yerr=std43,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A6U')
plt.errorbar(V44, avg44, yerr=std44,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4B1U_3')
plt.plot(V45, avg45, color = 'blue', ls='-',marker='*',mec='green',mfc='green',label = 'C4B2U_2')
plt.plot(V46, avg46, color = 'blue', ls='-',marker='*',mec='green',mfc='green',label = 'C4B1U_2')
plt.plot(V47, avg47, color = 'blue', ls='-',marker='*',mec='green',mfc='green',label = 'C4A6U_2')
plt.plot(V48, avg48, color = 'blue', ls='-',marker='*',mec='green',mfc='green',label = 'C4A5U_2')

plt.xlabel('Applied voltage (V)')
plt.ylabel('Angle (Deg)')
plt.legend()

# %%
V31 = C3A2D.iloc[:,0]
avg31 = C3A2D.iloc[:,4]
std31 = C3A2D.iloc[:,5]

V32 = C3A3D.iloc[:,0]
avg32 = C3A3D.iloc[:,4]
std32 = C3A3D.iloc[:,5]

V33 = C3E5D.iloc[:,0]
avg33 = C3E5D.iloc[:,4]
std33 = C3E5D.iloc[:,5]

V34 = C3E5D_2.iloc[:,0]
avg34 = C3E5D_2.iloc[:,1]

V41 = C4A3D.iloc[:,0]
avg41 = C4A3D.iloc[:,4]
std41 = C4A3D.iloc[:,5]

V42 = C4B1D.iloc[:,0]
avg42 = C4B1D.iloc[:,4]
std42 = C4B1D.iloc[:,5]

V43 = C4A6D.iloc[:,0]
avg43 = C4A6D.iloc[:,4]
std43 = C4A6D.iloc[:,5]

V44 = C4B2D_3.iloc[:,0]
avg44 = C4B2D_3.iloc[:,3]
std44 = C4B2D_3.iloc[:,4]

V45 = C4A4D_3.iloc[:,0]
avg45 = C4A4D_3.iloc[:,3]
std45 = C4A4D_3.iloc[:,4]

V46 = C4A1D_2.iloc[:,0]
avg46 = C4A1D_2.iloc[:,1]

V47 = C4A5D_2.iloc[:,0]
avg47 = C4A5D_2.iloc[:,1]

V48 = C4A4D_2.iloc[:,0]
avg48 = C4A4D_2.iloc[:,1]

plt.figure(figsize = (12,9))

plt.errorbar(V31, avg31, yerr=std31,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3A2D')
plt.errorbar(V32, avg32, yerr=std32,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3A3D')
plt.errorbar(V33, avg33, yerr=std33,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3E5D')
plt.plot(V34, avg34, ls='-',marker='s',mec='firebrick',mfc='pink',label = 'C3E5D_2')
plt.errorbar(V41, avg41, yerr=std41,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A3D')
plt.errorbar(V42, avg42, yerr=std42,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4B1D')
plt.errorbar(V43, avg43, yerr=std43,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A6D')
plt.errorbar(V44, avg44, yerr=std44,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4B2D_3')
plt.errorbar(V45, avg45, yerr=std45,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A4D_3')
plt.plot(V46, avg46, color='blue',ls='-',marker='*',mec='green',mfc='green',label = 'C4A1D_2')
plt.plot(V47, avg47, color='blue',ls='-',marker='*',mec='green',mfc='green',label = 'C4A5D_2')
plt.plot(V48, avg48, color='blue',ls='-',marker='*',mec='green',mfc='green',label = 'C4A4D_2')
plt.xlabel('Applied voltage (V)')
plt.ylabel('Angle (Deg)')
plt.legend()

# %%
V31 = C3A2U.iloc[:,0]
avg31 = C3A2U.iloc[:,4]
std31 = C3A2U.iloc[:,5]

V32 = C3A3U.iloc[:,0]
avg32 = C3A3U.iloc[:,4]
std32 = C3A3U.iloc[:,5]

V33 = C3E5U.iloc[:,0]
avg33 = C3E5U.iloc[:,4]
std33 = C3E5U.iloc[:,5]

V41 = C4A3U.iloc[:,0]
avg41 = C4A3U.iloc[:,4]
std41 = C4A3U.iloc[:,5]

V42 = C4B1U.iloc[:,0]
avg42 = C4B1U.iloc[:,4]
std42 = C4B1U.iloc[:,5]

V43 = C4A6U.iloc[:,0]
avg43 = C4A6U.iloc[:,4]
std43 = C4A6U.iloc[:,5]

NV31 = C3A2D.iloc[:,0]*-1
Navg31 = C3A2D.iloc[:,4]
Nstd31 = C3A2D.iloc[:,5]

NV32 = C3A3D.iloc[:,0]*-1
Navg32 = C3A3D.iloc[:,4]
Nstd32 = C3A3D.iloc[:,5]

NV33 = C3E5D.iloc[:,0]*-1
Navg33 = C3E5D.iloc[:,4]
Nstd33 = C3E5D.iloc[:,5]

NV34 = C3E5D_2.iloc[:,0]*-1
Navg34 = C3E5D_2.iloc[:,1]

NV41 = C4A3D.iloc[:,0]*-1
Navg41 = C4A3D.iloc[:,4]
Nstd41 = C4A3D.iloc[:,5]

NV42 = C4B1D.iloc[:,0]*-1
Navg42 = C4B1D.iloc[:,4]
Nstd42 = C4B1D.iloc[:,5]

NV43 = C4A6D.iloc[:,0]*-1
Navg43 = C4A6D.iloc[:,4]
Nstd43 = C4A6D.iloc[:,5]

NV44 = C4B2D_3.iloc[:,0]*-1
Navg44 = C4B2D_3.iloc[:,3]
Nstd44 = C4B2D_3.iloc[:,4]

NV45 = C4A4D_3.iloc[:,0]*-1
Navg45 = C4A4D_3.iloc[:,3]
Nstd45 = C4A4D_3.iloc[:,4]

NV46 = C4A1D_2.iloc[:,0]*-1
Navg46 = C4A1D_2.iloc[:,1]

NV47 = C4A5D_2.iloc[:,0]*-1
Navg47 = C4A5D_2.iloc[:,1]

NV48 = C4A4D_2.iloc[:,0]*-1
Navg48 = C4A4D_2.iloc[:,1]


plt.figure(figsize = (16,10))

plt.errorbar(NV31, Navg31, yerr=Nstd31,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3A2D')
plt.errorbar(NV32, Navg32, yerr=Nstd32,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3A3D')
plt.errorbar(NV33, Navg33, yerr=Nstd33,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3E5D')
plt.errorbar(NV41, Navg41, yerr=Nstd41,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A3D')
plt.errorbar(NV42, Navg42, yerr=Nstd42,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4B1D')
plt.errorbar(NV43, Navg43, yerr=Nstd43,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A6D')
plt.plot(NV34, Navg34, ls='-',marker='s',mec='firebrick',mfc='pink',label = 'C3E5D_2')
plt.errorbar(NV44, Navg44, yerr=Nstd44,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4B2D_3')
plt.errorbar(NV45, Navg45, yerr=Nstd45,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A4D_3')
plt.plot(NV46, Navg46, color='blue',ls='-',marker='*',mec='green',mfc='green',label = 'C4A1D_2')
plt.plot(NV47, Navg47, color='blue',ls='-',marker='*',mec='green',mfc='green',label = 'C4A5D_2')
plt.plot(NV48, Navg48, color='blue',ls='-',marker='*',mec='green',mfc='green',label = 'C4A4D_2')

plt.errorbar(V31, avg31, yerr=std31,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3A2U')
plt.errorbar(V32, avg32, yerr=std32,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3A3U')
plt.errorbar(V33, avg33, yerr=std33,ls='-',marker='s',mec='firebrick',ecolor='firebrick',mfc='pink',label = 'C3E5U')
plt.errorbar(V41, avg41, yerr=std41,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A3U')
plt.errorbar(V42, avg42, yerr=std42,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4B1U')
plt.errorbar(V43, avg43, yerr=std43,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4A6U')
plt.plot(V34, avg34, color='blue', ls='-',marker='s',mec='firebrick',mfc='pink',label = 'C3A4U_2')
plt.errorbar(V44, avg44, yerr=std44,ls='-',marker='*',mec='green',ecolor='green',mfc='green',label = 'C4B1U_3')
plt.plot(V45, avg45, color='blue', ls='-',marker='*',mec='green',mfc='green',label = 'C4B2U_2')
plt.plot(V46, avg46, color='blue', ls='-',marker='*',mec='green',mfc='green',label = 'C4B1U_2')
plt.plot(V47, avg47, color='blue', ls='-',marker='*',mec='green',mfc='green',label = 'C4A6U_2')
plt.plot(V48, avg48, color='blue', ls='-',marker='*',mec='green',mfc='green',label = 'C4A5U_2')
plt.axvline(x=V34.values[-2], label = 'x = '+str(V34.values[-2]))
plt.axvline(x=NV34.values[-2], label = 'x = '+str(NV34.values[-2]))
plt.axvline(x=V44.values[-2], label = 'x = '+str(V44.values[-2]))

plt.xlabel('Applied voltage (V)')
plt.ylabel('Angle (Deg)')
plt.legend()

# %%
NV47
# Out:
# 0    -0.00
# 1   -35.54
# 2   -45.60
# 3   -53.66
# 4   -63.41
# 5   -68.50
# 6   -73.00
# 7   -77.80
# 8   -83.20
# 9   -85.60
# Name: C4A5D, dtype: float64

# %%
V34.values[-2]
# Out:
# 86.0

# %%
type(V34)
# Out:
# pandas.core.series.Series
